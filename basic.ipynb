# %%
print("ygdhd")
# Out:
# ygdhd

# %%
dh= "ahsgdwfbhjew hchdy5 tfchf 5fjffdkfdjk mxhj xhnh jhnerhjt r4xjh  nxdnhdxhnx"

print(dh[:10])

stack = [1,3,5,7,9]
print(stack)

stack.append(10)
stack.append(13)
stack.append(11)
print(stack)

stack.pop()
print(stack)
# Out:
# ahsgdwfbhj
# [1, 3, 5, 7, 9]
# [1, 3, 5, 7, 9, 10, 13, 11]
# [1, 3, 5, 7, 9, 10, 13]

# %%
from collections import *
queue =deque([4,9,6,11,3,5])
print(queue)
queue.append(12)
print(queue)
queue.pop()
queue.popleft()
print(queue)
# Out:
# deque([4, 9, 6, 11, 3, 5])
# deque([4, 9, 6, 11, 3, 5, 12])
# deque([9, 6, 11, 3, 5])

# %%
tupple=  1,25,45,4,6,4
print(tupple)
lst= [1,5,98,7,5,6,8,"fty",5,58]
print(lst)
lst.append(60)
print(lst)
lst.pop()
print(lst)
lst.remove("fty")
print(lst)
lst.sort()
print(lst)
# Out:
# (1, 25, 45, 4, 6, 4)
# [1, 5, 98, 7, 5, 6, 8, 'fty', 5, 58]
# [1, 5, 98, 7, 5, 6, 8, 'fty', 5, 58, 60]
# [1, 5, 98, 7, 5, 6, 8, 'fty', 5, 58]
# [1, 5, 98, 7, 5, 6, 8, 5, 58]
# [1, 5, 5, 5, 6, 7, 8, 58, 98]

# %%
set = { 12,654,487,232,585,3,5,6,1,32,25,656,2552,4}
print(set)
print(232 in set)
print(set)
12 in set
print(10+2 in set)
a= {1,3,4,5,6 }
b= {9,7,6,5,}
print(a-b)
print(b-a)
print(a&b)
# Out:
# {32, 1, 3, 4, 5, 6, 487, 232, 585, 12, 654, 656, 2552, 25}
# True
# {32, 1, 3, 4, 5, 6, 487, 232, 585, 12, 654, 656, 2552, 25}
# True
# {1, 3, 4}
# {9, 7}
# {5, 6}

# %%
human ={
    "sojib": " sojib is a student ",
    "sahriyar" : " shahriyar is a programmer"}
print(human["sojib"])
print(human["sahriyar"])
# Out:
#  sojib is a student
#  shahriyar is a programmer

# %%
dust = { 45,2,3,56}

for dstbn in sorted(dust):
  print(dstbn)
# Out:
# 2
# 3
# 45
# 56

# %%
print(eval(input("calculate korte caaaw?\n")))
# Out:
# calculate korte caaaw?
# 100*3
# 300
